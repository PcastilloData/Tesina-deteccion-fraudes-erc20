# %% [markdown]
# # 0 Base de datos

# %%
#librerias
from google.cloud import bigquery
import pandas as pd
import time
import logging
import pandas as pd
import json

# %% [markdown]
# ## 0-1 Datos coingecko

# %%
import requests
import pandas as pd
import time
import numpy as np
from requests.exceptions import RequestException

# -----------------------------------------------
# Configuración
# -----------------------------------------------
COINS_TO_COLLECT = 500
API_COIN_MARKETS_URL = "https://api.coingecko.com/api/v3/coins/markets"
API_MARKET_CHART_URL = "https://api.coingecko.com/api/v3/coins/{}/market_chart"
REQUEST_DELAY = 1.5  # Pausa inicial, se ajusta con reintentos

# -----------------------------------------------
# Funciones de Recolección de Datos
# -----------------------------------------------
def get_crypto_list():
    """Obtiene una lista de las N criptomonedas principales."""
    all_coins = []
    page = 1
    while len(all_coins) < COINS_TO_COLLECT:
        params = {
            "vs_currency": "usd",
            "order": "market_cap_desc",
            "per_page": 250,
            "page": page
        }
        try:
            response = requests.get(API_COIN_MARKETS_URL, params=params)
            response.raise_for_status()
            data = response.json()
            if not data:
                break
            all_coins.extend(data)
            page += 1
            time.sleep(REQUEST_DELAY)
        except RequestException as e:
            print(f"Error al obtener la lista de monedas: {e}")
            break
    return all_coins[:COINS_TO_COLLECT]

def get_historical_features(coin_id, days=7, max_retries=5):
    """
    Obtiene y calcula características históricas para una moneda,
    con reintentos y manejo de errores 429.
    """
    url = API_MARKET_CHART_URL.format(coin_id)
    params = {"vs_currency": "usd", "days": days}

    for retry_count in range(max_retries):
        try:
            response = requests.get(url, params=params)
            if response.status_code == 429:
                # La API nos dice que esperemos.
                wait_time = int(response.headers.get("Retry-After", 60))
                print(f"Demasiadas solicitudes. Esperando {wait_time} segundos...")
                time.sleep(wait_time)
                continue # Reintentar

            response.raise_for_status()
            data = response.json()

            prices = [p[1] for p in data.get("prices", [])]
            volumes = [v[1] for v in data.get("total_volumes", [])]
            market_caps = [m[1] for m in data.get("market_caps", [])]

            if len(prices) < days or len(volumes) < days or len(market_caps) < days:
                return None

            features = {
                'price_initial': prices[0],
                'price_final': prices[-1],
                'price_pct_change_7d': ((prices[-1] - prices[0]) / prices[0]) * 100,
                'trading_volume_7d': np.sum(volumes),
                'market_cap_7d_avg': np.mean(market_caps),
                'vol_to_mcap_ratio': np.sum(volumes) / np.mean(market_caps),
                'price_std_dev_7d': np.std(prices),
                'price_max_7d': np.max(prices),
                'price_min_7d': np.min(prices)
            }
            return features
        except RequestException as e:
            print(f"Error al obtener datos históricos para {coin_id}: {e}")
            if retry_count < max_retries - 1:
                print("Reintentando...")
                time.sleep(2 ** retry_count) # Espera exponencial
            else:
                return None
    return None

# -----------------------------------------------
# Pipeline Principal
# -----------------------------------------------
if __name__ == "__main__":
    print("Iniciando la recolección de datos...")
    coin_list = get_crypto_list()
    if not coin_list:
        print("No se pudo obtener la lista inicial de monedas. Saliendo.")
        exit()

    dataset = []
    for idx, coin in enumerate(coin_list):
        print(f"Procesando moneda {idx+1}/{len(coin_list)}: {coin['id']}")

        market_features = get_historical_features(coin['id'])
        if not market_features:
            continue

        row = {
            'coin_id': coin['id'],
            'symbol': coin['symbol'],
            'name': coin['name'],
            'total_supply': coin.get('total_supply'),
            'circulating_supply': coin.get('circulating_supply'),
            'token_age_days': (pd.Timestamp.now() - pd.to_datetime(coin.get('genesis_date'))).days if coin.get('genesis_date') else None,
            **market_features
        }
        dataset.append(row)
        # Pausa para evitar el límite de tasa incluso con el reintento
        time.sleep(REQUEST_DELAY)

    df = pd.DataFrame(dataset)
    df.to_csv("crypto_market_dataset.csv", index=False)
    print(f"\n Dataset generado con éxito con {len(df)} registros.")
# Out:
# Iniciando la recolección de datos...
# Procesando moneda 1/500: bitcoin
# Procesando moneda 2/500: ethereum
# Procesando moneda 3/500: ripple
# Procesando moneda 4/500: tether
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 5/500: solana
# Procesando moneda 6/500: binancecoin
# Procesando moneda 7/500: usd-coin
# Procesando moneda 8/500: dogecoin
# Procesando moneda 9/500: staked-ether
# Procesando moneda 10/500: cardano
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 11/500: tron
# Procesando moneda 12/500: wrapped-steth
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 13/500: chainlink
# Procesando moneda 14/500: wrapped-beacon-eth
# Procesando moneda 15/500: hyperliquid
# Procesando moneda 16/500: wrapped-bitcoin
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 17/500: sui
# Procesando moneda 18/500: ethena-usde
# Procesando moneda 19/500: avalanche-2
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 20/500: stellar
# Procesando moneda 21/500: wrapped-eeth
# Procesando moneda 22/500: figure-heloc
# Procesando moneda 23/500: bitcoin-cash
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 24/500: weth
# Procesando moneda 25/500: hedera-hashgraph
# Procesando moneda 26/500: litecoin
# Procesando moneda 27/500: leo-token
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 28/500: crypto-com-chain
# Procesando moneda 29/500: shiba-inu
# Procesando moneda 30/500: the-open-network
# Procesando moneda 31/500: usds
# Procesando moneda 32/500: coinbase-wrapped-btc
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 33/500: polkadot
# Procesando moneda 34/500: binance-bridged-usdt-bnb-smart-chain
# Procesando moneda 35/500: whitebit
# Procesando moneda 36/500: uniswap
# Procesando moneda 37/500: ethena-staked-usde
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 38/500: world-liberty-financial
# Procesando moneda 39/500: mantle
# Procesando moneda 40/500: ethena
# Procesando moneda 41/500: monero
# Procesando moneda 42/500: pepe
# Procesando moneda 43/500: aave
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 44/500: bitget-token
# Procesando moneda 45/500: dai
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 46/500: okb
# Procesando moneda 47/500: memecore
# Procesando moneda 48/500: jito-staked-sol
# Procesando moneda 49/500: near
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 50/500: bittensor
# Procesando moneda 51/500: ondo-finance
# Procesando moneda 52/500: ethereum-classic
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 53/500: worldcoin-wld
# Procesando moneda 54/500: aptos
# Procesando moneda 55/500: pi-network
# Procesando moneda 56/500: story-2
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 57/500: polygon-ecosystem-token
# Procesando moneda 58/500: binance-staked-sol
# Procesando moneda 59/500: arbitrum
# Procesando moneda 60/500: binance-peg-weth
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 61/500: usdt0
# Procesando moneda 62/500: internet-computer
# Procesando moneda 63/500: usd1-wlfi
# Procesando moneda 64/500: myx-finance
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 65/500: kaspa
# Procesando moneda 66/500: pudgy-penguins
# Procesando moneda 67/500: cosmos
# Procesando moneda 68/500: pump-fun
# Procesando moneda 69/500: jupiter-perpetuals-liquidity-provider-token
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 70/500: blackrock-usd-institutional-digital-liquidity-fund
# Procesando moneda 71/500: algorand
# Procesando moneda 72/500: kinetic-staked-hype
# Procesando moneda 73/500: vechain
# Procesando moneda 74/500: rocket-pool-eth
# Procesando moneda 75/500: sei-network
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 76/500: render-token
# Procesando moneda 77/500: susds
# Procesando moneda 78/500: gatechain-token
# Procesando moneda 79/500: kelp-dao-restaked-eth
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 80/500: bonk
# Procesando moneda 81/500: kucoin-shares
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 82/500: fasttoken
# Procesando moneda 83/500: usdtb
# Procesando moneda 84/500: official-trump
# Procesando moneda 85/500: fetch-ai
# Demasiadas solicitudes. Esperando 60 segundos...
# Demasiadas solicitudes. Esperando 0 segundos...
# Procesando moneda 86/500: hash-2
# Procesando moneda 87/500: stakewise-v3-oseth
# Procesando moneda 88/500: filecoin
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 89/500: sky
# Procesando moneda 90/500: falcon-finance
# Procesando moneda 91/500: jupiter-exchange-solana
# Procesando moneda 92/500: liquid-staked-ethereum
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 93/500: bfusd
# Procesando moneda 94/500: flare-networks
# Procesando moneda 95/500: lombard-staked-btc
# Procesando moneda 96/500: quant-network
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 97/500: renzo-restaked-eth
# Procesando moneda 98/500: polygon-bridged-usdt-polygon
# Procesando moneda 99/500: celestia
# Procesando moneda 100/500: optimism
# Procesando moneda 101/500: injective-protocol
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 102/500: xdce-crowd-sale
# Procesando moneda 103/500: jupiter-staked-sol
# Procesando moneda 104/500: tether-gold
# Procesando moneda 105/500: mantle-staked-ether
# Procesando moneda 106/500: paypal-usd
# Procesando moneda 107/500: spx6900
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 108/500: immutable-x
# Procesando moneda 109/500: nexo
# Procesando moneda 110/500: wbnb
# Procesando moneda 111/500: blockstack
# Procesando moneda 112/500: sonic-3
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 113/500: solv-btc
# Procesando moneda 114/500: curve-dao-token
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 115/500: lido-dao
# Procesando moneda 116/500: aerodrome-finance
# Procesando moneda 117/500: first-digital-usd
# Procesando moneda 118/500: msol
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 119/500: syrupusdc
# Procesando moneda 120/500: the-graph
# Procesando moneda 121/500: super-oeth
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 122/500: binance-bridged-usdc-bnb-smart-chain
# Procesando moneda 123/500: pax-gold
# Procesando moneda 124/500: floki
# Procesando moneda 125/500: pyth-network
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 126/500: four
# Procesando moneda 127/500: raydium
# Procesando moneda 128/500: arbitrum-bridged-wbtc-arbitrum-one
# Procesando moneda 129/500: dogwifcoin
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 130/500: conflux-token
# Procesando moneda 131/500: kaia
# Procesando moneda 132/500: saros-finance
# Procesando moneda 133/500: cgeth-hashkey-cloud
# Procesando moneda 134/500: pancakeswap-token
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 135/500: fartcoin
# Procesando moneda 136/500: clbtc
# Procesando moneda 137/500: pendle
# Procesando moneda 138/500: theta-token
# Procesando moneda 139/500: virtual-protocol
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 140/500: gala
# Procesando moneda 141/500: tezos
# Procesando moneda 142/500: ethereum-name-service
# Procesando moneda 143/500: l2-standard-bridged-weth-base
# Procesando moneda 144/500: zcash
# Procesando moneda 145/500: iota
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 146/500: vaulta
# Procesando moneda 147/500: the-sandbox
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 148/500: jasmycoin
# Procesando moneda 149/500: jito-governance-token
# Procesando moneda 150/500: binance-peg-dogecoin
# Procesando moneda 151/500: ripple-usd
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 152/500: ousg
# Procesando moneda 153/500: stader-ethx
# Procesando moneda 154/500: morpho
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 155/500: ether-fi-staked-eth
# Procesando moneda 156/500: tbtc
# Procesando moneda 157/500: flow
# Procesando moneda 158/500: usdx-money-usdx
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 159/500: ondo-us-dollar-yield
# Procesando moneda 160/500: arbitrum-bridged-weth-arbitrum-one
# Procesando moneda 161/500: ether-fi
# Procesando moneda 162/500: coinbase-wrapped-staked-eth
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 163/500: decentraland
# Procesando moneda 164/500: aethir
# Procesando moneda 165/500: mantle-restaked-eth
# Procesando moneda 166/500: walrus-2
# Procesando moneda 167/500: newton-project
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 168/500: bittorrent
# Procesando moneda 169/500: sweth
# Procesando moneda 170/500: loaded-lions
# Procesando moneda 171/500: global-dollar
# Procesando moneda 172/500: beldex
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 173/500: starknet
# Procesando moneda 174/500: usual-usd
# Procesando moneda 175/500: based-brett
# Procesando moneda 176/500: vision-3
# Procesando moneda 177/500: build-on
# Procesando moneda 178/500: benqi-liquid-staked-avax
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 179/500: syrup
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 180/500: bitcoin-avalanche-bridged-btc-b
# Procesando moneda 181/500: bitcoin-cash-sv
# Procesando moneda 182/500: frax-ether
# Procesando moneda 183/500: dydx-chain
# Procesando moneda 184/500: polygon-pos-bridged-weth-polygon-pos
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 185/500: bybit-staked-sol
# Procesando moneda 186/500: eigenlayer
# Procesando moneda 187/500: apecoin
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 188/500: arweave
# Procesando moneda 189/500: keeta
# Procesando moneda 190/500: usdd
# Procesando moneda 191/500: true-usd
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 192/500: reserve-rights-token
# Procesando moneda 193/500: instadapp
# Procesando moneda 194/500: helium
# Procesando moneda 195/500: neo
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 196/500: telcoin
# Procesando moneda 197/500: coredaoorg
# Procesando moneda 198/500: mantle-bridged-usdt-mantle
# Procesando moneda 199/500: thorchain
# Procesando moneda 200/500: superstate-short-duration-us-government-securities-fund-ustb
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 201/500: zksync
# Procesando moneda 202/500: wormhole
# Procesando moneda 203/500: compound-governance-token
# Procesando moneda 204/500: wrapped-avax
# Procesando moneda 205/500: axie-infinity
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 206/500: polygon-pos-bridged-dai-polygon-pos
# Procesando moneda 207/500: apenft
# Procesando moneda 208/500: bridged-usdc-polygon-pos-bridge
# Procesando moneda 209/500: chiliz
# Procesando moneda 210/500: solv-protocol-solvbtc-bbn
# Procesando moneda 211/500: chain-2
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 212/500: reserve-protocol-eth-plus
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 213/500: steakhouse-usdc-morpho-vault
# Procesando moneda 214/500: rekt-4
# Procesando moneda 215/500: treehouse-eth
# Procesando moneda 216/500: elrond-erd-2
# Procesando moneda 217/500: drift-staked-sol
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 218/500: mog-coin
# Procesando moneda 219/500: ecash
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 220/500: beam-2
# Procesando moneda 221/500: hashnote-usyc
# Procesando moneda 222/500: aioz-network
# Procesando moneda 223/500: sun-token
# Procesando moneda 224/500: usdb
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 225/500: savings-dai
# Procesando moneda 226/500: dexe
# Procesando moneda 227/500: kava
# Procesando moneda 228/500: evervalue-coin
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 229/500: tokenize-xchange
# Procesando moneda 230/500: superfarm
# Procesando moneda 231/500: gnosis
# Procesando moneda 232/500: plume
# Procesando moneda 233/500: 1inch
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 234/500: wrapped-hype
# Procesando moneda 235/500: wrapped-ether-mantle-bridge
# Procesando moneda 236/500: unit-bitcoin
# Procesando moneda 237/500: olympus
# Procesando moneda 238/500: staked-frax-ether
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 239/500: ronin
# Procesando moneda 240/500: deep
# Procesando moneda 241/500: linea
# Procesando moneda 242/500: zebec-network
# Procesando moneda 243/500: eutbl
# Procesando moneda 244/500: snek
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 245/500: movement
# Procesando moneda 246/500: gho
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 247/500: axelar
# Procesando moneda 248/500: just
# Procesando moneda 249/500: trust-wallet-token
# Procesando moneda 250/500: terra-luna
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 251/500: akash-network
# Procesando moneda 252/500: wemix-token
# Procesando moneda 253/500: venom
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 254/500: resolv-usr
# Procesando moneda 255/500: livepeer
# Procesando moneda 256/500: eos
# Procesando moneda 257/500: arkham
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 258/500: dora-2
# Procesando moneda 259/500: convex-finance
# Procesando moneda 260/500: dash
# Procesando moneda 261/500: binance-peg-busd
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 262/500: turbo
# Procesando moneda 263/500: creditcoin-2
# Procesando moneda 264/500: berachain-bera
# Procesando moneda 265/500: polygon-bridged-wbtc-polygon-pos
# Procesando moneda 266/500: cat-in-a-dogs-world
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 267/500: ultima
# Procesando moneda 268/500: amp-token
# Procesando moneda 269/500: kaito
# Procesando moneda 270/500: frax
# Procesando moneda 271/500: safe
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 272/500: popcat
# Procesando moneda 273/500: swissborg
# Procesando moneda 274/500: bio-protocol
# Procesando moneda 275/500: decred
# Procesando moneda 276/500: tribe-2
# Procesando moneda 277/500: velo
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 278/500: kusama
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 279/500: satoshi-stablecoin
# Procesando moneda 280/500: useless-3
# Procesando moneda 281/500: qubic-network
# Procesando moneda 282/500: qtum
# Procesando moneda 283/500: openeden-open-dollar
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 284/500: toshi
# Procesando moneda 285/500: peanut-the-squirrel
# Procesando moneda 286/500: compound-wrapped-btc
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 287/500: btse-token
# Procesando moneda 288/500: binance-peg-sol
# Procesando moneda 289/500: iotex
# Procesando moneda 290/500: mocaverse
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 291/500: compounding-open-dollar
# Procesando moneda 292/500: frax-share
# Procesando moneda 293/500: astherus-staked-bnb
# Procesando moneda 294/500: grass
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 295/500: agentfun-ai
# Procesando moneda 296/500: resolv-wstusr
# Procesando moneda 297/500: nervos-network
# Procesando moneda 298/500: mx-token
# Procesando moneda 299/500: origin-ether
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 300/500: universal-btc
# Procesando moneda 301/500: usdx-money-staked-usdx
# Procesando moneda 302/500: cheems-token
# Procesando moneda 303/500: dog-go-to-the-moon-rune
# Procesando moneda 304/500: tdccp
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 305/500: theta-fuel
# Procesando moneda 306/500: havven
# Procesando moneda 307/500: usdai
# Procesando moneda 308/500: golem
# Procesando moneda 309/500: mina-protocol
# Procesando moneda 310/500: basic-attention-token
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 311/500: safepal
# Procesando moneda 312/500: ether-fi-staked-btc
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 313/500: vvs-finance
# Procesando moneda 314/500: drift-protocol
# Procesando moneda 315/500: euro-coin
# Procesando moneda 316/500: 0x
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 317/500: mantra-dao
# Procesando moneda 318/500: baby-doge-coin
# Procesando moneda 319/500: metaplex
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 320/500: blockchain-capital
# Procesando moneda 321/500: zilliqa
# Procesando moneda 322/500: layerzero
# Procesando moneda 323/500: zano
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 324/500: oasis-network
# Procesando moneda 325/500: gas
# Procesando moneda 326/500: blur
# Procesando moneda 327/500: restaking-vault-eth
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 328/500: ravencoin
# Procesando moneda 329/500: ordinals
# Procesando moneda 330/500: nxm
# Procesando moneda 331/500: zora
# Procesando moneda 332/500: agora-dollar
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 333/500: moo-deng
# Procesando moneda 334/500: gmt-token
# Procesando moneda 335/500: astar
# Procesando moneda 336/500: sahara-ai
# Procesando moneda 337/500: metal-blockchain
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 338/500: wrapped-aave-ethereum-weth
# Procesando moneda 339/500: unit-pump
# Procesando moneda 340/500: ignition-fbtc
# Procesando moneda 341/500: zetachain
# Procesando moneda 342/500: bridged-usd-coin-linea
# Procesando moneda 343/500: infrared-bera
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 344/500: notcoin
# Procesando moneda 345/500: non-playable-coin
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 346/500: origintrail
# Procesando moneda 347/500: ctc-plus
# Procesando moneda 348/500: openledger-2
# Procesando moneda 349/500: mimbogamegroup
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 350/500: usda-2
# Procesando moneda 351/500: ribbita-by-virtuals
# Procesando moneda 352/500: undeads-games
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 353/500: world-mobile-token
# Procesando moneda 354/500: legacy-token
# Procesando moneda 355/500: resolv-rlp
# Procesando moneda 356/500: yearn-finance
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 357/500: cow-protocol
# Procesando moneda 358/500: tradable-na-rent-financing-platform-sstn
# Procesando moneda 359/500: reallink
# Procesando moneda 360/500: sosovalue
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 361/500: proton
# Procesando moneda 362/500: celo
# Procesando moneda 363/500: ark-3
# Procesando moneda 364/500: succinct
# Procesando moneda 365/500: mag7-ssi
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 366/500: vethor-token
# Procesando moneda 367/500: ethereum-pow-iou
# Procesando moneda 368/500: compound-ether
# Procesando moneda 369/500: crypto-com-staked-eth
# Procesando moneda 370/500: kamino
# Procesando moneda 371/500: slash-vision-labs
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 372/500: oec-token
# Procesando moneda 373/500: cronos-bridged-usdc-cronos
# Procesando moneda 374/500: holotoken
# Procesando moneda 375/500: euler
# Procesando moneda 376/500: troll-2
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 377/500: skale
# Procesando moneda 378/500: redstone-oracles
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 379/500: okzoo
# Procesando moneda 380/500: siacoin
# Procesando moneda 381/500: centrifuge-2
# Procesando moneda 382/500: stargate-finance
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 383/500: polymesh
# Procesando moneda 384/500: threshold-network-token
# Procesando moneda 385/500: neiro-3
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 386/500: prometeus
# Procesando moneda 387/500: kinesis-gold
# Procesando moneda 388/500: harmony
# Procesando moneda 389/500: somnia
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 390/500: sushi
# Procesando moneda 391/500: yieldfi-ytoken
# Procesando moneda 392/500: kinesis-silver
# Procesando moneda 393/500: bnb48-club-token
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 394/500: phantom-staked-sol
# Procesando moneda 395/500: uxlink
# Procesando moneda 396/500: gmx
# Procesando moneda 397/500: ankr
# Procesando moneda 398/500: marsmi
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 399/500: mitosis-eol-bnb
# Procesando moneda 400/500: book-of-meme
# Procesando moneda 401/500: digibyte
# Procesando moneda 402/500: aelf
# Procesando moneda 403/500: melania-meme
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 404/500: sui-bridged-wbtc-sui
# Procesando moneda 405/500: memecoin-2
# Procesando moneda 406/500: chia
# Procesando moneda 407/500: altlayer
# Procesando moneda 408/500: avalanche-bridged-weth-avalanche
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 409/500: illuvium
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 410/500: merlin-chain
# Procesando moneda 411/500: rocket-pool
# Procesando moneda 412/500: orca
# Procesando moneda 413/500: icon
# Procesando moneda 414/500: conscious-token
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 415/500: coinex-token
# Procesando moneda 416/500: staked-hype
# Procesando moneda 417/500: stasis-eurs
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 418/500: xyo-network
# Procesando moneda 419/500: minidoge-5
# Procesando moneda 420/500: mbg-by-multibank-group
# Procesando moneda 421/500: holoworld
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 422/500: omni-network
# Procesando moneda 423/500: numeraire
# Procesando moneda 424/500: zignaly
# Procesando moneda 425/500: renzo-restaked-lst
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 426/500: ika
# Procesando moneda 427/500: stepn
# Procesando moneda 428/500: moonwell-flagship-eth-morpho-vault
# Procesando moneda 429/500: osaka-protocol
# Procesando moneda 430/500: woo-network
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 431/500: lcx
# Procesando moneda 432/500: vana
# Procesando moneda 433/500: bitkub-coin
# Procesando moneda 434/500: ai16z
# Procesando moneda 435/500: clearpool
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 436/500: kelp-gain
# Procesando moneda 437/500: enjincoin
# Procesando moneda 438/500: zencash
# Procesando moneda 439/500: babylon
# Procesando moneda 440/500: spiko-us-t-bills-money-market-fund
# Procesando moneda 441/500: degen-base
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 442/500: yield-guild-games
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 443/500: ket
# Procesando moneda 444/500: casper-network
# Procesando moneda 445/500: verus-coin
# Procesando moneda 446/500: rollbit-coin
# Procesando moneda 447/500: kadena
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 448/500: io
# Procesando moneda 449/500: hashkey-ecopoints
# Procesando moneda 450/500: mask-network
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 451/500: ontology
# Procesando moneda 452/500: gigachad-2
# Procesando moneda 453/500: api3
# Procesando moneda 454/500: osmosis
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 455/500: solo-coin
# Procesando moneda 456/500: band-protocol
# Procesando moneda 457/500: shuffle-2
# Procesando moneda 458/500: uma
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 459/500: elixir-deusd
# Procesando moneda 460/500: yu
# Procesando moneda 461/500: crvusd
# Procesando moneda 462/500: portal-to-bitcoin
# Procesando moneda 463/500: verasity
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 464/500: stp-network
# Procesando moneda 465/500: dola-usd
# Procesando moneda 466/500: coti
# Procesando moneda 467/500: loopring
# Procesando moneda 468/500: nano
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 469/500: blast
# Procesando moneda 470/500: aixbt
# Procesando moneda 471/500: f-x-protocol-fxusd
# Procesando moneda 472/500: magic-eden
# Procesando moneda 473/500: ai-companions
# Procesando moneda 474/500: swipe
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 475/500: ronin-bridged-weth-ronin
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 476/500: camp-network
# Procesando moneda 477/500: pythia
# Procesando moneda 478/500: anzen-usdz
# Procesando moneda 479/500: lorenzo-stbtc
# Procesando moneda 480/500: stronghold-token
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 481/500: solayer
# Procesando moneda 482/500: aura-on-sol
# Procesando moneda 483/500: sbtc-2
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 484/500: amnis-aptos
# Procesando moneda 485/500: gems-vip
# Procesando moneda 486/500: wrapped-centrifuge
# Procesando moneda 487/500: wilder-world
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 488/500: waves
# Procesando moneda 489/500: ozone-chain
# Procesando moneda 490/500: openvpp
# Procesando moneda 491/500: goatseus-maximus
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 492/500: bridged-wrapped-steth-gnosis
# Procesando moneda 493/500: constitutiondao
# Procesando moneda 494/500: wiki-cat
# Procesando moneda 495/500: chex-token
# Procesando moneda 496/500: unit-00-rei
# Demasiadas solicitudes. Esperando 60 segundos...
# Procesando moneda 497/500: savings-xdai
# Procesando moneda 498/500: echelon-prime
# Procesando moneda 499/500: infinifi-usd
# Procesando moneda 500/500: avant-usd
#
# ✅ Dataset generado con éxito con 499 registros.

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            coin_id symbol           name  total_supply  circulating_supply  \
# 0          bitcoin    btc        Bitcoin  1.991993e+07        1.991993e+07
# 1         ethereum    eth       Ethereum  1.207047e+08        1.207047e+08
# 2           ripple    xrp            XRP  9.998581e+10        5.961021e+10
# 3           tether   usdt         Tether  1.700017e+11        1.700017e+11
# 4           solana    sol         Solana  6.096105e+08        5.424453e+08
# ..             ...    ...            ...           ...                 ...
# 494    unit-00-rei    rei            Rei  1.000000e+09        1.000000e+09
# 495   savings-xdai   sdai   Savings xDAI  9.521845e+07        9.521845e+07
# 496  echelon-prime  prime  Echelon Prime  1.111111e+08        5.423475e+07
# 497   infinifi-usd   iusd   InfiniFi USD  1.140314e+08        1.140314e+08
# 498      avant-usd  avusd      Avant USD  1.141788e+08        1.141788e+08
#
#     token_age_days  price_initial    price_final  price_pct_change_7d  \
# 0             None  110948.472864  116027.132618             4.577494
# 1             None    4310.327362    4731.800520             9.778217
# 2             None       2.815578       3.142431            11.608731
# 3             None       1.000200       1.000522             0.032238
# 4             None     203.458286     243.353848            19.608718
# ..             ...            ...            ...                  ...
# 494           None       0.080541       0.113572            41.011983
# 495           None       1.198286       1.200474             0.182649
# 496           None       1.929540       2.102743             8.976390
# 497           None       0.999281       0.999825             0.054502
# 498           None       1.000352       1.000016            -0.033624
#
#      trading_volume_7d  market_cap_7d_avg  vol_to_mcap_ratio  \
# 0         6.538951e+12       2.247384e+12           2.909583
# 1         4.581493e+12       5.294169e+11           8.653847
# 2         7.874663e+11       1.764789e+11           4.462098
# 3         1.383871e+13       1.691455e+11          81.815381
# 4         1.411340e+12       1.187202e+11          11.887945
# ..                 ...                ...                ...
# 494       2.269285e+08       9.158080e+07           2.477904
# 495       6.234544e+08       1.127335e+08           5.530337
# 496       2.853682e+08       1.082025e+08           2.637353
# 497       4.551065e+07       1.160526e+08           0.392155
# 498       6.619549e+07       1.059774e+08           0.624619
#
#      price_std_dev_7d   price_max_7d   price_min_7d
# 0         1879.124874  116704.714866  110054.773314
# 1          126.099903    4762.735941    4256.038325
# 2            0.089036       3.142431       2.794460
# 3            0.000179       1.001015       0.999934
# 4           12.990398     243.697395     199.801551
# ..                ...            ...            ...
# 494          0.017573       0.121124       0.070803
# 495          0.001618       1.203458       1.193386
# 496          0.040211       2.118448       1.913086
# 497          0.000471       1.004009       0.998361
# 498          0.001395       1.005704       0.994325
#
# [499 rows x 15 columns]>

# %% [markdown]
# ## 0-2 Datos Bigquery google

# %% [markdown]
# ### 0-2-1 feature On-chain

# %%
from google.cloud import bigquery
import pandas as pd

# Conexión con tu credencial JSON
client = bigquery.Client.from_service_account_json("key.json")

# Query mínima funcional: características básicas de 50 tokens distintos
query = """
WITH token_summary AS (
  SELECT
    token_address,
    COUNT(*) AS num_transfers,
    COUNT(DISTINCT from_address) + COUNT(DISTINCT to_address) AS approx_holders,
    MIN(block_timestamp) AS first_seen,
    MAX(block_timestamp) AS last_seen
  FROM `bigquery-public-data.crypto_ethereum.token_transfers`
  GROUP BY token_address
)
SELECT *
FROM token_summary
ORDER BY num_transfers DESC
LIMIT 50
"""

# Ejecutar query y traer resultados a DataFrame
df = client.query(query).to_dataframe()

# Calcular feature adicional: antigüedad en días
df['age_days'] = (pd.to_datetime(df['last_seen']) - pd.to_datetime(df['first_seen'])).dt.days

# Guardar CSV para usar como dataset de prueba
df.to_csv("dataset_tokens_prueba.csv", index=False)

print("CSV generado con éxito: dataset_tokens_prueba.csv")
print(df.head())
# Out:
# CSV generado con éxito: dataset_tokens_prueba.csv
#                                 token_address  num_transfers  approx_holders  \
# 0  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2      402779564         6975935
# 1  0xdac17f958d2ee523a2206206994597c13d831ec7      351766979        96320277
# 2  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48      171087577        39228183
# 3  0x06450dee7fd2fb8e39061434babcfc05599a6fb8       44376023        12383080
# 4  0x6b175474e89094c44da98b954eedeac495271d0f       24569101         4966372
#
#                  first_seen                 last_seen  age_days
# 0 2017-12-18 09:07:58+00:00 2025-09-14 08:33:23+00:00      2826
# 1 2017-11-28 15:38:10+00:00 2025-09-14 08:33:23+00:00      2846
# 2 2018-09-10 18:26:41+00:00 2025-09-14 08:33:23+00:00      2560
# 3 2022-10-08 18:03:59+00:00 2025-09-14 08:33:11+00:00      1071
# 4 2019-11-13 21:22:33+00:00 2025-09-14 08:33:23+00:00      2131

# %%
from google.cloud import bigquery

client = bigquery.Client.from_service_account_json("key.json")

# Query para ver las columnas reales de la tabla tokens
query = """
SELECT *
FROM `bigquery-public-data.crypto_ethereum.tokens`
LIMIT 5
"""

df = client.query(query).to_dataframe()

print("✅ Preview de tokens:")
print(df.head())
print("\n📌 Columnas disponibles:")
print(df.columns.tolist())
# Out:
# ✅ Preview de tokens:
#                                       address symbol       name decimals  \
# 0  0x81a7d1f0c28189a0b083521d5e3ac4b6c04149ad   DOPE  Dope Boyz     None
# 1  0x461c5448a753b70fe509c67d8c5954ac1112105c   GLDC   GoldCoin       18
# 2  0x3b987b27992fe7f665b3f43d8485cafbec8fcbba  sosal     sosal?       18
# 3  0x2724b281344acb7536439aabd018ac8bd980d2fb    YZY        YZY        9
# 4  0xdc34889e6255be40373e2b9410782240a466b7e8    YZY        YZY        9
#
#                    total_supply           block_timestamp  block_number  \
# 0                             1 2025-08-24 16:19:59+00:00      23212101
# 1  1000000000000000000000000000 2025-08-24 23:30:23+00:00      23214248
# 2                             0 2025-08-20 19:26:35+00:00      23184372
# 3            100000000000000000 2025-08-21 04:38:11+00:00      23187120
# 4            100000000000000000 2025-08-21 04:30:35+00:00      23187082
#
#                                           block_hash
# 0  0xfb6b66a487d50279ff112cedd4de97606095d1a6b98c...
# 1  0x9334c62e260599006be3b2e612d009dcb5cced3e07f4...
# 2  0x52103c1ea2872a859a68a30b6a79c8bd8c1d8f5d1d1a...
# 3  0x0f1b5c7fed928bef9dac240f52e9a1a7ebede3be5bdf...
# 4  0x324742f858ef7b2bc6c9296ea758bd2c108cc3b241d6...
#
# 📌 Columnas disponibles:
# ['address', 'symbol', 'name', 'decimals', 'total_supply', 'block_timestamp', 'block_number', 'block_hash']

# %%
from google.cloud import bigquery
import pandas as pd

# Cliente
client = bigquery.Client.from_service_account_json("key.json")

# Query mínima para prueba de tipos y fechas
query_test = """
SELECT
  token_address,
  MIN(SAFE_CAST(block_timestamp AS TIMESTAMP)) AS first_seen,
  MAX(SAFE_CAST(block_timestamp AS TIMESTAMP)) AS last_seen,
  COUNT(*) AS num_transfers
FROM `bigquery-public-data.crypto_ethereum.token_transfers`
GROUP BY token_address
LIMIT 5
"""

df_test = client.query(query_test).to_dataframe()

# Mostrar tipos y data
print("✅ Tipos de columnas:")
print(df_test.dtypes)
print("\n✅ Preview de datos:")
print(df_test)
# Out:
# ✅ Tipos de columnas:
# token_address                 object
# first_seen       datetime64[us, UTC]
# last_seen        datetime64[us, UTC]
# num_transfers                  Int64
# dtype: object
#
# ✅ Preview de datos:
#                                 token_address                first_seen  \
# 0  0xd0d6d6c5fe4a677d343cc433536bb717bae167dd 2017-06-19 19:53:58+00:00
# 1  0x3fbabe48e137c9ef4f8cb517a4762add7e6242ae 2024-06-29 04:28:59+00:00
# 2  0xa1afffe3f4d611d252010e3eaf6f4d77088b0cd7 2020-11-18 21:25:26+00:00
# 3  0xfa99a87b14b02e2240c79240c5a20f945ca5ef76 2020-12-07 19:04:54+00:00
# 4  0xd06b49243b3b0a873b51b8636cc138832532d7fa 2020-11-29 01:24:51+00:00
#
#                   last_seen  num_transfers
# 0 2025-09-02 13:18:11+00:00          17818
# 1 2025-09-14 21:12:35+00:00          14347
# 2 2025-09-09 07:56:47+00:00          75384
# 3 2025-09-14 14:02:35+00:00          20584
# 4 2024-04-11 10:31:59+00:00           1653

# %%
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client.from_service_account_json("key.json")

# Query corregida con agregación adecuada
query = """
WITH token_summary AS (
  SELECT
    token_address,
    COUNT(*) AS num_transfers,
    COUNT(DISTINCT from_address) + COUNT(DISTINCT to_address) AS approx_holders,
    MIN(block_timestamp) AS first_seen,
    MAX(block_timestamp) AS last_seen
  FROM `bigquery-public-data.crypto_ethereum.token_transfers`
  GROUP BY token_address
),
top10_holders AS (
  SELECT
    token_address,
    SUM(total_value) AS top10_balance
  FROM (
    SELECT
      token_address,
      to_address,
      SUM(SAFE_CAST(value AS FLOAT64)) AS total_value,
      ROW_NUMBER() OVER(
        PARTITION BY token_address
        ORDER BY SUM(SAFE_CAST(value AS FLOAT64)) DESC
      ) AS rn
    FROM `bigquery-public-data.crypto_ethereum.token_transfers`
    GROUP BY token_address, to_address
  )
  WHERE rn <= 10
  GROUP BY token_address
),
daily_stats AS (
  SELECT
    token_address,
    AVG(tx_count) AS avg_transfers_per_day,
    STDDEV(tx_count) AS std_transfers_per_day,
    COUNT(*) AS active_days
  FROM (
    SELECT
      token_address,
      DATE(block_timestamp) AS day,
      COUNT(*) AS tx_count
    FROM `bigquery-public-data.crypto_ethereum.token_transfers`
    GROUP BY token_address, day
  )
  GROUP BY token_address
)
SELECT
  ts.token_address AS address,
  t.symbol,
  t.name,
  ts.num_transfers,
  ts.approx_holders,
  ts.first_seen,
  ts.last_seen,
  SAFE_DIVIDE(th.top10_balance, ts.num_transfers) AS top10_concentration_proxy,
  ds.avg_transfers_per_day,
  ds.std_transfers_per_day,
  ds.active_days
FROM token_summary ts
LEFT JOIN top10_holders th ON ts.token_address = th.token_address
LEFT JOIN daily_stats ds ON ts.token_address = ds.token_address
LEFT JOIN `bigquery-public-data.crypto_ethereum.tokens` t
  ON ts.token_address = t.address
ORDER BY ts.num_transfers DESC
LIMIT 10
"""

# Ejecutar query
df = client.query(query).to_dataframe()

# Convertir timestamps a datetime en Python
df['first_seen'] = pd.to_datetime(df['first_seen'])
df['last_seen'] = pd.to_datetime(df['last_seen'])

# Calcular métricas derivadas en Python
df['age_days'] = (df['last_seen'] - df['first_seen']).dt.days
df['inactive_days_proxy'] = df['age_days'] - df['active_days']

# Guardar CSV
df.to_csv("dataset_tokens_extendido.csv", index=False)

print("✅ CSV generado: dataset_tokens_extendido.csv")
print(df.head(10))
# Out:
# ✅ CSV generado: dataset_tokens_extendido.csv
#                                       address symbol             name  \
# 0  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   WETH    Wrapped Ether
# 1  0xdac17f958d2ee523a2206206994597c13d831ec7   USDT       Tether USD
# 2  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48   None             None
# 3  0x06450dee7fd2fb8e39061434babcfc05599a6fb8   None             None
# 4  0x6b175474e89094c44da98b954eedeac495271d0f   None             None
# 5  0x514910771af9ca656af840dff83e8264ecf986ca   LINK  ChainLink Token
# 6  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce   SHIB        SHIBA INU
# 7  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599   WBTC      Wrapped BTC
# 8  0x0000000000a39bb272e79075ade125fd351887ac   None             None
# 9  0x174bfa6600bf90c885c7c01c7031389ed1461ab9    MGC   More Gold Coin
#
#    num_transfers  approx_holders                first_seen  \
# 0      402961481         6977804 2017-12-18 09:07:58+00:00
# 1      351975575        96365967 2017-11-28 15:38:10+00:00
# 2      171277918        39256239 2018-09-10 18:26:41+00:00
# 3       44389630        12387545 2022-10-08 18:03:59+00:00
# 4       24576760         4967735 2019-11-13 21:22:33+00:00
# 5       18953512         6714908 2017-09-16 21:29:09+00:00
# 6       16242925         8632716 2020-07-31 18:32:43+00:00
# 7       12890403         1244933 2018-11-27 16:12:05+00:00
# 8        9651259          707306 2022-12-04 02:44:23+00:00
# 9        8947724          736211 2019-01-23 06:37:42+00:00
#
#                   last_seen  top10_concentration_proxy  avg_transfers_per_day  \
# 0 2025-09-14 21:33:59+00:00               9.143692e+18          142489.915488
# 1 2025-09-14 21:33:59+00:00               6.004397e+09          125795.416369
# 2 2025-09-14 21:33:59+00:00               3.569571e+10           67115.171630
# 3 2025-09-14 21:31:47+00:00               4.754136e+25           41369.645853
# 4 2025-09-14 21:33:59+00:00               2.707489e+23           11532.970436
# 5 2025-09-14 21:33:35+00:00               3.404585e+20            6495.377656
# 6 2025-09-14 21:33:11+00:00               7.995156e+26            8822.881586
# 7 2025-09-14 21:33:59+00:00               8.777296e+07            5304.692593
# 8 2025-09-14 21:32:35+00:00               8.210634e+17            9499.270669
# 9 2025-09-08 03:44:59+00:00               1.431539e+20           17753.420635
#
#    std_transfers_per_day  active_days  age_days  inactive_days_proxy
# 0          117487.716758         2828      2827                   -1
# 1           87533.646522         2798      2847                   49
# 2           68492.585951         2552      2561                    9
# 3           31051.818836         1073      1072                   -1
# 4            6492.687964         2131      2132                    1
# 5            5900.862673         2918      2920                    2
# 6           11311.738727         1841      1871                   30
# 7            5198.654730         2430      2483                   53
# 8           10584.709583         1016      1015                   -1
# 9           55314.788885          504      2419                 1915

# %%
import pandas as pd

# Cargar dataset generado
df = pd.read_csv("dataset_tokens_extendido.csv")

# Convertir timestamps a datetime
df['first_seen'] = pd.to_datetime(df['first_seen'])
df['last_seen'] = pd.to_datetime(df['last_seen'])

# --- Función de análisis de features ---
def feature_summary(df):
    summary = []

    for col in df.columns:
        dtype = df[col].dtype
        n_unique = df[col].nunique()
        n_missing = df[col].isna().sum()
        perc_missing = 100 * n_missing / len(df)
        min_val = df[col].min() if pd.api.types.is_numeric_dtype(df[col]) else None
        max_val = df[col].max() if pd.api.types.is_numeric_dtype(df[col]) else None
        mean_val = df[col].mean() if pd.api.types.is_numeric_dtype(df[col]) else None
        summary.append({
            'feature': col,
            'dtype': dtype,
            'n_unique': n_unique,
            'n_missing': n_missing,
            'perc_missing': perc_missing,
            'min': min_val,
            'max': max_val,
            'mean': mean_val
        })

    return pd.DataFrame(summary)

# Generar resumen
feature_info = feature_summary(df)

# Mostrar resumen
print("✅ Resumen de features:")
print(feature_info)

# --- Opcional: revisar correlación entre features numéricas ---
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
corr_matrix = df[num_cols].corr()

print("\n✅ Matriz de correlación:")
print(corr_matrix)

# --- Opcional: guardar resumen a CSV ---
feature_info.to_csv("feature_summary.csv", index=False)
corr_matrix.to_csv("feature_correlation.csv")
# Out:
# ✅ Resumen de features:
#                       feature                dtype  n_unique  n_missing  \
# 0                     address               object        10          0
# 1                      symbol               object         6          4
# 2                        name               object         6          4
# 3               num_transfers                int64        10          0
# 4              approx_holders                int64        10          0
# 5                  first_seen  datetime64[ns, UTC]        10          0
# 6                   last_seen  datetime64[ns, UTC]         6          0
# 7   top10_concentration_proxy              float64        10          0
# 8       avg_transfers_per_day              float64        10          0
# 9       std_transfers_per_day              float64        10          0
# 10                active_days                int64        10          0
# 11                   age_days                int64        10          0
# 12        inactive_days_proxy                int64         8          0
#
#     perc_missing           min           max          mean
# 0            0.0           NaN           NaN           NaN
# 1           40.0           NaN           NaN           NaN
# 2           40.0           NaN           NaN           NaN
# 3            0.0  8.947724e+06  4.029615e+08  1.061867e+08
# 4            0.0  7.073060e+05  9.636597e+07  1.779914e+07
# 5            0.0           NaN           NaN           NaN
# 6            0.0           NaN           NaN           NaN
# 7            0.0  8.777296e+07  7.995156e+26  8.473282e+25
# 8            0.0  5.304693e+03  1.424899e+05  4.361788e+04
# 9            0.0  5.198655e+03  1.174877e+05  3.993692e+04
# 10           0.0  5.040000e+02  2.918000e+03  2.009100e+03
# 11           0.0  1.015000e+03  2.920000e+03  2.214700e+03
# 12           0.0 -1.000000e+00  1.915000e+03  2.056000e+02
#
# ✅ Matriz de correlación:
#                            num_transfers  approx_holders  \
# num_transfers                   1.000000        0.627793
# approx_holders                  0.627793        1.000000
# top10_concentration_proxy      -0.218355       -0.112362
# avg_transfers_per_day           0.988531        0.627738
# std_transfers_per_day           0.911176        0.503920
# active_days                     0.557811        0.410065
# age_days                        0.502297        0.350633
# inactive_days_proxy            -0.221738       -0.184612
#
#                            top10_concentration_proxy  avg_transfers_per_day  \
# num_transfers                              -0.218355               0.988531
# approx_holders                             -0.112362               0.627738
# top10_concentration_proxy                   1.000000              -0.238876
# avg_transfers_per_day                      -0.238876               1.000000
# std_transfers_per_day                      -0.255895               0.937565
# active_days                                -0.091134               0.460522
# age_days                                   -0.208465               0.422721
# inactive_days_proxy                        -0.110426              -0.173747
#
#                            std_transfers_per_day  active_days  age_days  \
# num_transfers                           0.911176     0.557811  0.502297
# approx_holders                          0.503920     0.410065  0.350633
# top10_concentration_proxy              -0.255895    -0.091134 -0.208465
# avg_transfers_per_day                   0.937565     0.460522  0.422721
# std_transfers_per_day                   1.000000     0.274127  0.456380
# active_days                             0.274127     1.000000  0.724968
# age_days                                0.456380     0.724968  1.000000
# inactive_days_proxy                     0.134136    -0.601146  0.114622
#
#                            inactive_days_proxy
# num_transfers                        -0.221738
# approx_holders                       -0.184612
# top10_concentration_proxy            -0.110426
# avg_transfers_per_day                -0.173747
# std_transfers_per_day                 0.134136
# active_days                          -0.601146
# age_days                              0.114622
# inactive_days_proxy                   1.000000

# %% [markdown]
# ## 0-3 Consultas finales

# %% [markdown]
# ### 0-3-1 consulta final coingecko "id", "symbol", "name", "current_price", "market_cap", "total_volume"

# %%
import requests
import pandas as pd
import time

vs_currency = "usd"
per_page = 250
max_pages = 60  # Limite máximo de páginas para Coingecko
all_coins = []

for page in range(1, max_pages + 1):
    print(f"✅ Descargando página {page}/{max_pages}...")

    url = "https://api.coingecko.com/api/v3/coins/markets"
    params = {
        "vs_currency": vs_currency,
        "order": "market_cap_desc",
        "per_page": per_page,
        "page": page,
        "sparkline": "false"
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
    except Exception as e:
        print(f"❌ Error en request o parseo JSON en página {page}: {e}")
        break

    # Validar que venga una lista
    if isinstance(data, list) and data:
        all_coins.extend(data)
    else:
        print(f"❌ Respuesta inesperada o vacía en página {page}: {data}")
        break

    # Rate limit seguro: Coingecko permite ~30 llamadas/min, aquí 2 seg entre llamadas
    time.sleep(20)

if all_coins:
    df = pd.DataFrame(all_coins)
    # Seleccionar solo columnas relevantes
    df = df[["id", "symbol", "name", "current_price", "market_cap", "total_volume"]]
    df.to_csv("coingecko_tokens2.csv", index=False)
    print(f"✅ Guardado CSV con {len(df)} tokens: coingecko_tokens2.csv")
else:
    print("❌ No se descargaron tokens")
# Out:
# ✅ Descargando página 1/60...
# ✅ Descargando página 2/60...
# ✅ Descargando página 3/60...
# ✅ Descargando página 4/60...
# ✅ Descargando página 5/60...
# ✅ Descargando página 6/60...
# ✅ Descargando página 7/60...
# ✅ Descargando página 8/60...
# ✅ Descargando página 9/60...
# ✅ Descargando página 10/60...
# ✅ Descargando página 11/60...
# ✅ Descargando página 12/60...
# ✅ Descargando página 13/60...
# ✅ Descargando página 14/60...
# ✅ Descargando página 15/60...
# ✅ Descargando página 16/60...
# ✅ Descargando página 17/60...
# ✅ Descargando página 18/60...
# ✅ Descargando página 19/60...
# ✅ Descargando página 20/60...
# ✅ Descargando página 21/60...
# ✅ Descargando página 22/60...
# ✅ Descargando página 23/60...
# ✅ Descargando página 24/60...
# ✅ Descargando página 25/60...
# ✅ Descargando página 26/60...
# ✅ Descargando página 27/60...
# ✅ Descargando página 28/60...
# ✅ Descargando página 29/60...
# ✅ Descargando página 30/60...
# ✅ Descargando página 31/60...
# ✅ Descargando página 32/60...
# ✅ Descargando página 33/60...
# ✅ Descargando página 34/60...
# ✅ Descargando página 35/60...
# ✅ Descargando página 36/60...
# ✅ Descargando página 37/60...
# ✅ Descargando página 38/60...
# ✅ Descargando página 39/60...
# ✅ Descargando página 40/60...
# ✅ Descargando página 41/60...
# ✅ Descargando página 42/60...
# ✅ Descargando página 43/60...
# ✅ Descargando página 44/60...
# ✅ Descargando página 45/60...
# ✅ Descargando página 46/60...
# ✅ Descargando página 47/60...
# ✅ Descargando página 48/60...
# ✅ Descargando página 49/60...
# ✅ Descargando página 50/60...
# ✅ Descargando página 51/60...
# ✅ Descargando página 52/60...
# ✅ Descargando página 53/60...
# ✅ Descargando página 54/60...
# ✅ Descargando página 55/60...
# ✅ Descargando página 56/60...
# ✅ Descargando página 57/60...
# ✅ Descargando página 58/60...
# ✅ Descargando página 59/60...
# ✅ Descargando página 60/60...
# ✅ Guardado CSV con 15000 tokens: coingecko_tokens2.csv

# %%
print(df)
# Out:
#                      id symbol              name  current_price    market_cap  \
# 0               bitcoin    btc           Bitcoin  115432.000000  2.301122e+12
# 1              ethereum    eth          Ethereum    4611.930000  5.566856e+11
# 2                ripple    xrp               XRP       3.030000  1.808420e+11
# 3                tether   usdt            Tether       1.001000  1.703268e+11
# 4                solana    sol            Solana     241.230000  1.309971e+11
# ...                 ...    ...               ...            ...           ...
# 14995           num-ars   nars           Num ARS       0.000676  0.000000e+00
# 14996    purple-bitcoin   pbtc    Purple Bitcoin       0.359607  0.000000e+00
# 14997         ponke-ton  ponke         Ponke TON       0.000077  0.000000e+00
# 14998              pola   pola      Pola On Base       0.000050  0.000000e+00
# 14999  mxmboxceus-token    mbe  MxmBoxcEus Token       0.026741  0.000000e+00
#
#        total_volume
# 0      2.645448e+10
# 1      2.389103e+10
# 2      4.739631e+09
# 3      7.545703e+10
# 4      9.623193e+09
# ...             ...
# 14995  5.147970e+05
# 14996  2.534340e+05
# 14997  7.700000e+00
# 14998  3.462500e+02
# 14999  1.481000e+01
#
# [15000 rows x 6 columns]

# %% [markdown]
# ### 0-3-2 consulta final bigquery optimizado

# %%
from google.cloud import bigquery
import pandas as pd
import time
import logging

# Configurar logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Cliente BigQuery
client = bigquery.Client.from_service_account_json("key.json")

# Parámetros
BATCH_SIZE = 100
MAX_BYTES_BILLED = 500 * 1024**3  # 500 GB
MIN_TRANSFERS = 10  # Filtrar tokens con menos de 10 transfers
MAX_TOKENS = 500    # Total tokens para tu análisis

# Paso 1: Obtener tokens válidos con filtro desde el inicio
logger.info("Obteniendo tokens válidos filtrados por transferencias...")
tokens_query = f"""
WITH token_counts AS (
  SELECT
    t.address,
    COUNT(tt.token_address) AS num_transfers
  FROM `bigquery-public-data.crypto_ethereum.tokens` t
  LEFT JOIN `bigquery-public-data.crypto_ethereum.token_transfers` tt
    ON t.address = tt.token_address
  WHERE t.symbol IS NOT NULL AND t.name IS NOT NULL
  GROUP BY t.address
  HAVING COUNT(tt.token_address) >= {MIN_TRANSFERS}
)
SELECT address
FROM token_counts
LIMIT {MAX_TOKENS}
"""
tokens_df = client.query(tokens_query).to_dataframe()
tokens = tokens_df['address'].tolist()
logger.info(f"Encontrados {len(tokens)} tokens válidos y útiles")

# Paso 2: Procesar tokens en batches
all_results = []
for i in range(0, len(tokens), BATCH_SIZE):
    batch = tokens[i:i + BATCH_SIZE]
    token_list = ", ".join([f"'{t}'" for t in batch])

    query = f"""
    WITH token_summary AS (
      SELECT
        token_address,
        COUNT(*) AS num_transfers,
        COUNT(DISTINCT from_address) + COUNT(DISTINCT to_address) AS approx_holders,
        MIN(block_timestamp) AS first_seen,
        MAX(block_timestamp) AS last_seen
      FROM `bigquery-public-data.crypto_ethereum.token_transfers`
      WHERE token_address IN ({token_list})
      GROUP BY token_address
    ),
    top10_holders AS (
      SELECT
        token_address,
        SUM(total_value) AS top10_balance
      FROM (
        SELECT
          token_address,
          to_address,
          SUM(SAFE_CAST(value AS FLOAT64)) AS total_value,
          ROW_NUMBER() OVER(
            PARTITION BY token_address
            ORDER BY SUM(SAFE_CAST(value AS FLOAT64)) DESC
          ) AS rn
        FROM `bigquery-public-data.crypto_ethereum.token_transfers`
        WHERE token_address IN ({token_list})
        GROUP BY token_address, to_address
      )
      WHERE rn <= 10
      GROUP BY token_address
    ),
    daily_stats AS (
      SELECT
        token_address,
        AVG(tx_count) AS avg_transfers_per_day,
        STDDEV(tx_count) AS std_transfers_per_day,
        COUNT(*) AS active_days
      FROM (
        SELECT
          token_address,
          DATE(block_timestamp) AS day,
          COUNT(*) AS tx_count
        FROM `bigquery-public-data.crypto_ethereum.token_transfers`
        WHERE token_address IN ({token_list})
        GROUP BY token_address, day
      )
      GROUP BY token_address
    )
    SELECT
      ts.token_address AS address,
      t.symbol,
      t.name,
      ts.num_transfers,
      ts.approx_holders,
      ts.first_seen,
      ts.last_seen,
      SAFE_DIVIDE(th.top10_balance, ts.num_transfers) AS top10_concentration_proxy,
      ds.avg_transfers_per_day,
      ds.std_transfers_per_day,
      ds.active_days
    FROM token_summary ts
    LEFT JOIN top10_holders th ON ts.token_address = th.token_address
    LEFT JOIN daily_stats ds ON ts.token_address = ds.token_address
    LEFT JOIN `bigquery-public-data.crypto_ethereum.tokens` t
      ON ts.token_address = t.address
    """

    try:
        df_batch = client.query(query, job_config=bigquery.QueryJobConfig(
            maximum_bytes_billed=MAX_BYTES_BILLED
        )).to_dataframe()

        if not df_batch.empty:
            all_results.append(df_batch)
            logger.info(f"Lote {i//BATCH_SIZE + 1} procesado, {len(df_batch)} tokens")
        time.sleep(1)  # Pausa para proteger recursos
    except Exception as e:
        logger.error(f"Error en lote {i//BATCH_SIZE + 1}: {e}")

# Paso 3: Combinar resultados finales
if all_results:
    df = pd.concat(all_results, ignore_index=True)
    df['first_seen'] = pd.to_datetime(df['first_seen'])
    df['last_seen'] = pd.to_datetime(df['last_seen'])
    df['age_days'] = (df['last_seen'] - df['first_seen']).dt.days
    df['inactive_days_proxy'] = df['age_days'] - df['active_days']

    df.to_csv("token_analysis_filtered.csv", index=False)
    logger.info(f"✅ CSV generado: token_analysis_filtered.csv con {len(df)} tokens")
else:
    logger.warning("❌ No se obtuvieron resultados")
# Out:
# INFO:__main__:Obteniendo tokens válidos filtrados por transferencias...
# INFO:__main__:Encontrados 500 tokens válidos y útiles
# INFO:__main__:Lote 1 procesado, 100 tokens
# INFO:__main__:Lote 2 procesado, 100 tokens
# INFO:__main__:Lote 3 procesado, 100 tokens
# INFO:__main__:Lote 4 procesado, 100 tokens
# INFO:__main__:Lote 5 procesado, 100 tokens
# INFO:__main__:✅ CSV generado: token_analysis_filtered.csv con 500 tokens

# %% [markdown]
# ### 0-3-2-1 Uso de GCP
# En GCP se gasto 5 query de Tiempo total de ranura
# 2 h 37 min
# Duración
# Bytes procesados
# 403.92 GB
# Registros leídos: 2700610582
# Registros escritos: 17202
# cada query o id de trabajo.
#
# analogo al batch de 200 por eso para la query final se sube el tamaño de batch dee 100 a 250.

# %%
# Configurar logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Cliente BigQuery
client = bigquery.Client.from_service_account_json("key.json")

# Parámetros
BATCH_SIZE = 250
MAX_BYTES_BILLED = 500 * 1024**3  # 500 GB
MIN_TRANSFERS = 10  # Filtrar tokens con menos de 10 transfers
MAX_TOKENS = 5000    # Total tokens para tu análisis

# Paso 1: Obtener tokens válidos con filtro desde el inicio
logger.info("Obteniendo tokens válidos filtrados por transferencias...")
tokens_query = f"""
WITH token_counts AS (
  SELECT
    t.address,
    COUNT(tt.token_address) AS num_transfers
  FROM `bigquery-public-data.crypto_ethereum.tokens` t
  LEFT JOIN `bigquery-public-data.crypto_ethereum.token_transfers` tt
    ON t.address = tt.token_address
  WHERE t.symbol IS NOT NULL AND t.name IS NOT NULL
  GROUP BY t.address
  HAVING COUNT(tt.token_address) >= {MIN_TRANSFERS}
)
SELECT address
FROM token_counts
LIMIT {MAX_TOKENS}
"""
tokens_df = client.query(tokens_query).to_dataframe()
tokens = tokens_df['address'].tolist()
logger.info(f"Encontrados {len(tokens)} tokens válidos y útiles")

# Paso 2: Procesar tokens en batches
all_results = []
for i in range(0, len(tokens), BATCH_SIZE):
    batch = tokens[i:i + BATCH_SIZE]
    token_list = ", ".join([f"'{t}'" for t in batch])

    query = f"""
    WITH token_summary AS (
      SELECT
        token_address,
        COUNT(*) AS num_transfers,
        COUNT(DISTINCT from_address) + COUNT(DISTINCT to_address) AS approx_holders,
        MIN(block_timestamp) AS first_seen,
        MAX(block_timestamp) AS last_seen
      FROM `bigquery-public-data.crypto_ethereum.token_transfers`
      WHERE token_address IN ({token_list})
      GROUP BY token_address
    ),
    top10_holders AS (
      SELECT
        token_address,
        SUM(total_value) AS top10_balance
      FROM (
        SELECT
          token_address,
          to_address,
          SUM(SAFE_CAST(value AS FLOAT64)) AS total_value,
          ROW_NUMBER() OVER(
            PARTITION BY token_address
            ORDER BY SUM(SAFE_CAST(value AS FLOAT64)) DESC
          ) AS rn
        FROM `bigquery-public-data.crypto_ethereum.token_transfers`
        WHERE token_address IN ({token_list})
        GROUP BY token_address, to_address
      )
      WHERE rn <= 10
      GROUP BY token_address
    ),
    daily_stats AS (
      SELECT
        token_address,
        AVG(tx_count) AS avg_transfers_per_day,
        STDDEV(tx_count) AS std_transfers_per_day,
        COUNT(*) AS active_days
      FROM (
        SELECT
          token_address,
          DATE(block_timestamp) AS day,
          COUNT(*) AS tx_count
        FROM `bigquery-public-data.crypto_ethereum.token_transfers`
        WHERE token_address IN ({token_list})
        GROUP BY token_address, day
      )
      GROUP BY token_address
    )
    SELECT
      ts.token_address AS address,
      t.symbol,
      t.name,
      ts.num_transfers,
      ts.approx_holders,
      ts.first_seen,
      ts.last_seen,
      SAFE_DIVIDE(th.top10_balance, ts.num_transfers) AS top10_concentration_proxy,
      ds.avg_transfers_per_day,
      ds.std_transfers_per_day,
      ds.active_days
    FROM token_summary ts
    LEFT JOIN top10_holders th ON ts.token_address = th.token_address
    LEFT JOIN daily_stats ds ON ts.token_address = ds.token_address
    LEFT JOIN `bigquery-public-data.crypto_ethereum.tokens` t
      ON ts.token_address = t.address
    """

    try:
        df_batch = client.query(query, job_config=bigquery.QueryJobConfig(
            maximum_bytes_billed=MAX_BYTES_BILLED
        )).to_dataframe()

        if not df_batch.empty:
            all_results.append(df_batch)
            logger.info(f"Lote {i//BATCH_SIZE + 1} procesado, {len(df_batch)} tokens")
        time.sleep(1)  # Pausa para proteger recursos
    except Exception as e:
        logger.error(f"Error en lote {i//BATCH_SIZE + 1}: {e}")

# Paso 3: Combinar resultados finales
if all_results:
    df = pd.concat(all_results, ignore_index=True)
    df['first_seen'] = pd.to_datetime(df['first_seen'])
    df['last_seen'] = pd.to_datetime(df['last_seen'])
    df['age_days'] = (df['last_seen'] - df['first_seen']).dt.days
    df['inactive_days_proxy'] = df['age_days'] - df['active_days']

    df.to_csv("bd_onchain_final.csv", index=False)
    logger.info(f"✅ CSV generado: bd_onchain_final.csv con {len(df)} tokens")
else:
    logger.warning("❌ No se obtuvieron resultados")
# Out:
# INFO:__main__:Obteniendo tokens válidos filtrados por transferencias...
# INFO:__main__:Encontrados 5000 tokens válidos y útiles
# INFO:__main__:Lote 1 procesado, 250 tokens
# INFO:__main__:Lote 2 procesado, 250 tokens
# INFO:__main__:Lote 3 procesado, 250 tokens
# INFO:__main__:Lote 4 procesado, 250 tokens
# INFO:__main__:Lote 5 procesado, 250 tokens
# INFO:__main__:Lote 6 procesado, 250 tokens
# INFO:__main__:Lote 7 procesado, 250 tokens
# INFO:__main__:Lote 8 procesado, 250 tokens
# INFO:__main__:Lote 9 procesado, 250 tokens
# INFO:__main__:Lote 10 procesado, 250 tokens
# INFO:__main__:Lote 11 procesado, 250 tokens
# INFO:__main__:Lote 12 procesado, 250 tokens
# INFO:__main__:Lote 13 procesado, 250 tokens
# INFO:__main__:Lote 14 procesado, 250 tokens
# INFO:__main__:Lote 15 procesado, 250 tokens
# INFO:__main__:Lote 16 procesado, 250 tokens
# INFO:__main__:Lote 17 procesado, 250 tokens
# INFO:__main__:Lote 18 procesado, 250 tokens
# INFO:__main__:Lote 19 procesado, 250 tokens
# INFO:__main__:Lote 20 procesado, 250 tokens
# INFO:__main__:✅ CSV generado: bd_onchain_final.csv con 5000 tokens

# %%
import pandas as pd

# Cargar dataset generado
df = pd.read_csv("bd_onchain_final.csv")

# Convertir timestamps a datetime
df['first_seen'] = pd.to_datetime(df['first_seen'])
df['last_seen'] = pd.to_datetime(df['last_seen'])

# --- Función de análisis de features ---
def feature_summary(df):
    summary = []

    for col in df.columns:
        dtype = df[col].dtype
        n_unique = df[col].nunique()
        n_missing = df[col].isna().sum()
        perc_missing = 100 * n_missing / len(df)
        min_val = df[col].min() if pd.api.types.is_numeric_dtype(df[col]) else None
        max_val = df[col].max() if pd.api.types.is_numeric_dtype(df[col]) else None
        mean_val = df[col].mean() if pd.api.types.is_numeric_dtype(df[col]) else None
        summary.append({
            'feature': col,
            'dtype': dtype,
            'n_unique': n_unique,
            'n_missing': n_missing,
            'perc_missing': perc_missing,
            'min': min_val,
            'max': max_val,
            'mean': mean_val
        })

    return pd.DataFrame(summary)

# Generar resumen
feature_info = feature_summary(df)

# Mostrar resumen
print("✅ Resumen de features:")
print(feature_info)

# --- Opcional: revisar correlación entre features numéricas ---
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
corr_matrix = df[num_cols].corr()

print("\n✅ Matriz de correlación:")
print(corr_matrix)
# Out:
# ✅ Resumen de features:
#                       feature                dtype  n_unique  n_missing  \
# 0                     address               object      5000          0
# 1                      symbol               object      4323          0
# 2                        name               object      4829          0
# 3               num_transfers                int64      1655          0
# 4              approx_holders                int64      1414          0
# 5                  first_seen  datetime64[ns, UTC]      4993          0
# 6                   last_seen  datetime64[ns, UTC]      4945          0
# 7   top10_concentration_proxy              float64      4968          0
# 8       avg_transfers_per_day              float64      3131          0
# 9       std_transfers_per_day              float64      3875        446
# 10                active_days                int64       569          0
# 11                   age_days                int64      1683          0
# 12        inactive_days_proxy                int64      1550          0
#
#     perc_missing   min           max          mean
# 0           0.00   NaN           NaN           NaN
# 1           0.00   NaN           NaN           NaN
# 2           0.00   NaN           NaN           NaN
# 3           0.00  10.0  8.947724e+06  9.155689e+03
# 4           0.00   2.0  1.507632e+06  3.786241e+03
# 5           0.00   NaN           NaN           NaN
# 6           0.00   NaN           NaN           NaN
# 7           0.00   0.0  6.947525e+76  3.366348e+73
# 8           0.00   1.0  1.998900e+04  5.148393e+01
# 9           8.92   0.0  5.531479e+04  1.176841e+02
# 10          0.00   1.0  3.079000e+03  9.125000e+01
# 11          0.00   0.0  3.297000e+03  5.875540e+02
# 12          0.00  -2.0  3.047000e+03  4.963040e+02
#
# ✅ Matriz de correlación:
#                            num_transfers  approx_holders  \
# num_transfers                   1.000000        0.674146
# approx_holders                  0.674146        1.000000
# top10_concentration_proxy      -0.001620       -0.002890
# avg_transfers_per_day           0.548592        0.268016
# std_transfers_per_day           0.801104        0.388646
# active_days                     0.252083        0.463445
# age_days                        0.138530        0.242019
# inactive_days_proxy             0.059709        0.094725
#
#                            top10_concentration_proxy  avg_transfers_per_day  \
# num_transfers                              -0.001620               0.548592
# approx_holders                             -0.002890               0.268016
# top10_concentration_proxy                   1.000000              -0.002467
# avg_transfers_per_day                      -0.002467               1.000000
# std_transfers_per_day                      -0.002795               0.895907
# active_days                                -0.006192               0.037061
# age_days                                    0.016759               0.024995
# inactive_days_proxy                         0.022492               0.014278
#
#                            std_transfers_per_day  active_days  age_days  \
# num_transfers                           0.801104     0.252083  0.138530
# approx_holders                          0.388646     0.463445  0.242019
# top10_concentration_proxy              -0.002795    -0.006192  0.016759
# avg_transfers_per_day                   0.895907     0.037061  0.024995
# std_transfers_per_day                   1.000000     0.083211  0.103912
# active_days                             0.083211     1.000000  0.591802
# age_days                                0.103912     0.591802  1.000000
# inactive_days_proxy                     0.088005     0.287084  0.942049
#
#                            inactive_days_proxy
# num_transfers                         0.059709
# approx_holders                        0.094725
# top10_concentration_proxy             0.022492
# avg_transfers_per_day                 0.014278
# std_transfers_per_day                 0.088005
# active_days                           0.287084
# age_days                              0.942049
# inactive_days_proxy                   1.000000

# %%
df.head(10)
# Out:
#                                       address symbol             name  \
# 0  0x2a2c06306f1352b7e742bb09eb421f91ffa2791a    TBL              TBL
# 1  0x9b613bb970ef1f8dd15f9da863fe6b059c20dfb6    CYC              CYC
# 2  0x74004a7227615fb52b82d17ffabfa376907d8a4d    AVM       AVM Tokens
# 3  0x05271b76b10c785358f531281138e2b296821905    CHZ           Cholyz
# 4  0x3c4bea627039f0b7e7d21e34bb9c9fe962977518    UCT             UCOT
# 5  0xd964d2ddba0c50e535d09b80630cb8cd88c5c9ef   CT-💯                💯
# 6  0x3a358e34c7774a8cd7c916a594454701f27f380e     AT        AutoToken
# 7  0x1d5bd914b57aeb1ce91d37d8454dfa48be22eb60  RGX15  RGX (x15) Token
# 8  0x9750ce7823568c9354720407e2763fd16bf0b1c6    FMC             FOMO
# 9  0xa18e33b88312a14e5f34253152540e36bac279b3   UVCN             UVCN
#
#    num_transfers  approx_holders                first_seen  \
# 0            114              86 2018-10-30 08:39:13+00:00
# 1             11              10 2018-04-20 10:03:19+00:00
# 2             54              46 2018-04-26 04:15:44+00:00
# 3             11               5 2019-08-10 00:03:56+00:00
# 4          26616           22887 2018-01-30 04:45:34+00:00
# 5             18              10 2018-02-21 20:32:30+00:00
# 6           2710            2748 2018-07-05 17:16:20+00:00
# 7             12              15 2017-09-12 17:15:43+00:00
# 8          30925           22174 2019-05-10 01:53:48+00:00
# 9             28              30 2018-03-22 11:13:08+00:00
#
#                   last_seen  top10_concentration_proxy  avg_transfers_per_day  \
# 0 2021-01-13 23:18:44+00:00               9.112790e+24               2.850000
# 1 2018-05-10 05:20:41+00:00               1.482727e+24               1.571429
# 2 2021-06-30 03:01:56+00:00               1.386268e+24               1.350000
# 3 2019-08-10 04:23:01+00:00               1.480000e+10              11.000000
# 4 2025-09-11 01:45:59+00:00               1.686164e+23              25.666345
# 5 2018-03-03 00:48:54+00:00               1.000000e+08               6.000000
# 6 2023-03-25 02:33:59+00:00               3.787799e+19              31.511628
# 7 2018-06-28 11:06:23+00:00               7.916583e+03               1.333333
# 8 2023-10-26 15:03:47+00:00               1.791051e+21             222.482014
# 9 2018-09-30 10:59:41+00:00               1.428572e+27               1.750000
#
#    std_transfers_per_day  active_days  age_days  inactive_days_proxy
# 0               2.402456           40       806                  766
# 1               1.133893            7        19                   12
# 2               0.769615           40      1160                 1120
# 3                    NaN            1         0                   -1
# 4             226.132817         1037      2780                 1743
# 5               6.928203            3         9                    6
# 6             198.834175           86      1723                 1637
# 7               0.707107            9       288                  279
# 8             574.330516          139      1630                 1491
# 9               0.930949           16       191                  175

# %% [markdown]
# ## 0-4 BD fraudes

# %%
# 1Cargar diccionario de tokens de TokenScout
with open("token-dict.json", "r", encoding="utf-8") as f:
    token_dict = json.load(f)

# Convertir a DataFrame: address | token_id
df_tokens = pd.DataFrame(list(token_dict.items()), columns=["address", "token_id"])

# Cargar CSV de etiquetas procesadas: tokens | t1-labels | t2-labels
df_labels = pd.read_csv("token_labels_processed.csv")  # tokens = id

# Hacer merge de etiquetas con diccionario de tokens por token_id
df_labels = df_labels.merge(df_tokens, left_on="tokens", right_on="token_id", how="left")

# Crear columna organization y eliminar columnas intermedias
df_labels["organization"] = "TokenScout"
df_final = df_labels[["address", "organization", "t1-labels", "t2-labels"]]

# Guardar CSV limpio
df_final.to_csv("tokenscout_labels_clean.csv", index=False)

print("✅ CSV TokenScout limpio creado: tokenscout_labels_clean.csv")
# Out:
# ✅ CSV TokenScout limpio creado: tokenscout_labels_clean.csv

# %%
import pandas as pd

# Cargar archivo principal
df_main = pd.read_csv("bd_onchain_final.csv", dtype=str)

# 2Cargar CSV limpio de TokenScout
df_tokenscout = pd.read_csv("tokenscout_labels_clean.csv", dtype=str)

# 3Merge izquierdo por address
df_merged = df_main.merge(
    df_tokenscout,
    on="address",
    how="left"
)

# Rellenar valores faltantes con default
df_merged["organization"] = df_merged["organization"].fillna("0")
df_merged["t1-labels"] = df_merged["t1-labels"].fillna("0")
df_merged["t2-labels"] = df_merged["t2-labels"].fillna("0")
new_cols = ["organization", "t1-labels", "t2-labels"]

for col in new_cols:
    print(f"--- {col} ---")
    print(f"Cantidad de valores únicos: {df_merged[col].nunique()}")
    print(f"Cantidad de registros con 0: {(df_merged[col] == '0').sum()}")
    print(f"Distribución de valores:\n{df_merged[col].value_counts()}\n")

# Guardar CSV final
df_merged.to_csv("bd_onchain_final_with_tokenscout.csv", index=False)

print("✅ Archivo principal combinado con TokenScout creado.")
# Out:
# --- organization ---
# Cantidad de valores únicos: 2
# Cantidad de registros con 0: 288
# Distribución de valores:
# organization
# TokenScout    4712
# 0              288
# Name: count, dtype: int64
#
# --- t1-labels ---
# Cantidad de valores únicos: 3
# Cantidad de registros con 0: 288
# Distribución de valores:
# t1-labels
# scam           4542
# 0               288
# truthworthy     170
# Name: count, dtype: int64
#
# --- t2-labels ---
# Cantidad de valores únicos: 5
# Cantidad de registros con 0: 288
# Distribución de valores:
# t2-labels
# rugpull        3352
# honeypot        732
# ponzi           458
# 0               288
# truthworthy     170
# Name: count, dtype: int64
#
# ✅ Archivo principal combinado con TokenScout creado.

# %%
# Cargar archivos
df_main = pd.read_csv("bd_onchain_final_with_tokenscout.csv", dtype=str)
df_coingecko = pd.read_csv("coingecko_tokens2.csv", dtype=str)

# Limpiar nombres de columnas por si hay espacios
df_main.columns = df_main.columns.str.strip()
df_coingecko.columns = df_coingecko.columns.str.strip()

# Columnas de Coingecko a agregar
coingecko_cols = [col for col in df_coingecko.columns if col != "symbol"]

# Merge izquierdo por 'symbol'
df_final = df_main.merge(
    df_coingecko[["symbol"] + coingecko_cols],
    on="symbol",
    how="left"
)

# Verifica qué columnas realmente están en df_final
print("Columnas en df_final:", df_final.columns.tolist())

# Rellenar valores faltantes solo para columnas que existen
for col in coingecko_cols:
    if col in df_final.columns:
        df_final[col] = df_final[col].fillna("0")
    else:
        print(f"⚠️ Columna {col} no existe en df_final, se omite.")

# Guardar CSV final
df_final.to_csv("bd_onchain_final_with_tokenscout_coingecko.csv", index=False)
print("✅ Archivo final combinado creado correctamente.")
# Out:
# Columnas en df_final: ['address', 'symbol', 'name_x', 'num_transfers', 'approx_holders', 'first_seen', 'last_seen', 'top10_concentration_proxy', 'avg_transfers_per_day', 'std_transfers_per_day', 'active_days', 'age_days', 'inactive_days_proxy', 'organization', 't1-labels', 't2-labels', 'id', 'name_y', 'current_price', 'market_cap', 'total_volume']
# ⚠️ Columna name no existe en df_final, se omite.
# ✅ Archivo final combinado creado correctamente.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# Crear carpeta para gráficos
os.makedirs("graficos_bd_onchain", exist_ok=True)

# Cargar CSV final
df = pd.read_csv("bd_onchain_final_with_tokenscout_coingecko.csv", dtype=str)
df2=pd.read_csv("coingecko_tokens2.csv")
summary = []

# Columnas categóricas y numéricas a graficar
cat_cols = ['organization', 't1-labels', 't2-labels']
num_cols = ['num_transfers', 'approx_holders', 'top10_concentration_proxy',
            'avg_transfers_per_day', 'std_transfers_per_day', 'active_days',
            'age_days', 'inactive_days_proxy', 'current_price', 'market_cap', 'total_volume']

# Analizar todas las columnas
for col in df.columns:
    col_data = df[col]

    # Intentar convertir a numérico
    col_numeric = pd.to_numeric(col_data, errors='coerce')

    summary.append({
        "column": col,
        "dtype": col_data.dtype,
        "n_unique": col_data.nunique(),
        "n_null_or_empty": col_data.isna().sum() + (col_data == '').sum(),
        "top_5_values": col_data.value_counts().head(5).to_dict(),
        "mean": col_numeric.replace([np.inf, -np.inf], np.nan).mean(),
        "std": col_numeric.replace([np.inf, -np.inf], np.nan).std(),
        "min": col_numeric.replace([np.inf, -np.inf], np.nan).min(),
        "max": col_numeric.replace([np.inf, -np.inf], np.nan).max(),
        "median": col_numeric.replace([np.inf, -np.inf], np.nan).median()
    })

    # Graficar categóricas relevantes
    if col in cat_cols:
        counts = col_data.value_counts()
        plt.figure(figsize=(8,4))
        counts.plot(kind='bar', color='skyblue')
        plt.title(f"Distribución de {col}")
        plt.ylabel("Frecuencia")
        plt.tight_layout()
        plt.savefig(f"graficos_bd_onchain/{col}_bar.png")
        plt.close()

    # Graficar numéricas relevantes
    elif col in num_cols:
        numeric_clean = col_numeric.replace([np.inf, -np.inf], np.nan).dropna()
        if not numeric_clean.empty:
            plt.figure(figsize=(8,4))
            plt.hist(numeric_clean, bins=50, color='lightgreen', edgecolor='black')
            plt.title(f"Histograma de {col}")
            plt.xlabel(col)
            plt.ylabel("Frecuencia")
            plt.tight_layout()
            plt.savefig(f"graficos_bd_onchain/{col}_hist.png")
            plt.close()

# Guardar resumen en CSV
df_summary = pd.DataFrame(summary)
df_summary.to_csv("resumen_estadistico_completo_bd_onchain.csv", index=False)

print("✅ Resumen estadístico completo generado y gráficos guardados en 'graficos_bd_onchain/'")
# Out:
# C:\Users\win10\AppData\Roaming\Python\Python310\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   >>> a[0, 1] = np.nan
# C:\Users\win10\AppData\Roaming\Python\Python310\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   >>> a[0, 1] = np.nan
# C:\Users\win10\AppData\Roaming\Python\Python310\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   >>> a[0, 1] = np.nan
# ✅ Resumen estadístico completo generado y gráficos guardados en 'graficos_bd_onchain/'
